# %%
import numpy as np
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from benchmark_base import sample_main

# %%
sns.set_palette("viridis")

# %% [markdown]
# Run benchmark to evaluate performance across various problem sizes and and iterations of the ant system algorithm.

# %%
NUMBER_OF_ANTS = 25 # number of ants in the system
INITIAL_PHEROMONE_VALUE = 1.0 # initial pheromone value for each edge
DISTANCE_INFLUENCE = 2.0 # influence of distance on route
PHEROMONE_INFLUENCE = 1.0 # influence of pheromone on route
PHEROMONE_DEPOSIT = 1.0 # pheromone deposit factor
EVAPORATION_RATE = 0.2 # pheromone evaporation rate

# %% [markdown]
# Define base set of parameters for the Ant System Algorithm except max_iterations as we will change it throughout the benchmark.

# %%
RUN_SAMPLES = 5 # run this many samples for each problem

data_list = []
for problem_size in ["SMALL", "MEDIUM", "LARGE"]:
    for MAX_ITERATIONS in [10, 25, 50, 100, 200, 300, 400, 500]:
        average_samples = np.zeros((7)) # 7 parameters

        for run in range(RUN_SAMPLES):
            return_values = sample_main(problem_size, MAX_ITERATIONS, NUMBER_OF_ANTS, INITIAL_PHEROMONE_VALUE, DISTANCE_INFLUENCE, PHEROMONE_INFLUENCE, PHEROMONE_DEPOSIT, EVAPORATION_RATE) # evaluate the sample
            sample_array = np.array(return_values)
            average_samples += sample_array # add each sample to the average

        average_samples /= RUN_SAMPLES # divide by the number of samples to get the average

        data_list.append({'algorithm': 'Ant System', 'problem_size': problem_size.lower(), 'max_iterations': MAX_ITERATIONS, 'distance': average_samples[0], 'time_taken': average_samples[1]}) # append the ant system sample to data list

benchmark_df = pd.DataFrame(data_list) # create a dataframe from the data list

# %% [markdown]
# Run the benchmarks with changing max iterations and group it into a dataframe for visualization later.

# %%
sns.lineplot(benchmark_df, x="max_iterations", y="distance", hue="problem_size", marker='o', markersize=8, palette="muted")
plt.xlabel("Max Iterations")
plt.ylabel("Distance")
plt.title("Performance of Ant System With Increasing Max Iterations")
# Out:
# Text(0.5, 1.0, 'Performance of Ant System With Increasing Max Iterations')

# %% [markdown]
# Check performance across max iterations and various problem sizes.
